# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
from scipy import stats

plt.style.use('ggplot')

#폰트 적용 방법 1 - 설정 파일에서 폰트 적용

#설정파일위치확인
print('버전', mpl.__version__)
print('설치 위치', mpl.__file__)
print('설정 위치', mpl.get_configdir())
print('캐시 위치', mpl.get_cachedir())
print('설정 파일 위치', mpl.matplotlib_fname())

fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('설정 파일에서 폰트 적용')

fm._rebuild()
for i in fm.fontManager.ttflist:
    if "Gmarket" in i.name:
        print(i)

myHelperUrl = "https://studioplug.tistory.com/333"
# Out:
# 버전 3.1.2
# 설치 위치 /usr/local/lib/python3.7/site-packages/matplotlib/__init__.py
# 설정 위치 /root/.config/matplotlib
# 캐시 위치 /root/.cache/matplotlib
# 설정 파일 위치 /usr/local/lib/python3.7/site-packages/matplotlib/mpl-data/matplotlibrc
# <Font 'Gmarket Sans TTF' (GmarketSansTTFLight.ttf) normal normal light normal>
# <Font 'Gmarket Sans TTF' (GmarketSansTTFBold.ttf) normal normal bold normal>
# <Font 'Gmarket Sans TTF' (GmarketSansTTFMedium.ttf) normal normal medium normal>

# %%
plt.show()

# %%
#모든ttf폰트
font_list = fm.findSystemFonts(fontpaths=None, fontext='ttf')

print(len(font_list))
print(font_list)
# Out:
# 134
# ['/usr/share/fonts/truetype/msttcorefonts/Courier_New_Bold.ttf', '/usr/share/fonts/truetype/ttf-bitstream-vera/VeraSeBd.ttf', '/usr/share/fonts/truetype/msttcorefonts/trebucbi.ttf', '/usr/share/fonts/truetype/Gmarketfont/GmarketSansTTFLight.ttf', '/usr/share/fonts/truetype/msttcorefonts/trebuc.ttf', '/usr/share/fonts/truetype/msttcorefonts/Trebuchet_MS_Bold_Italic.ttf', '/usr/share/fonts/truetype/lyx/stmary10.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSans.ttf', '/usr/share/fonts/truetype/lyx/eufm10.ttf', '/usr/share/fonts/truetype/msttcorefonts/Verdana_Bold_Italic.ttf', '/usr/share/fonts/truetype/msttcorefonts/trebucit.ttf', '/usr/share/fonts/truetype/ttf-bitstream-vera/VeraMono.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf', '/usr/share/fonts/truetype/msttcorefonts/Times_New_Roman.ttf', '/usr/share/fonts/truetype/msttcorefonts/Verdana_Bold.ttf', '/usr/share/fonts/truetype/msttcorefonts/Verdana.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSerifCondensed-BoldItalic.ttf', '/usr/share/fonts/truetype/liberation/LiberationSansNarrow-Bold.ttf', '/usr/share/fonts/truetype/msttcorefonts/Courier_New_Bold_Italic.ttf', '/usr/share/fonts/truetype/msttcorefonts/Arial_Bold.ttf', '/usr/share/fonts/truetype/lyx/cmr10.ttf', '/usr/share/fonts/truetype/msttcorefonts/times.ttf', '/usr/share/fonts/truetype/msttcorefonts/comic.ttf', '/usr/share/fonts/truetype/msttcorefonts/Webdings.ttf', '/usr/share/fonts/truetype/unfonts-core/UnGungseo.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-BoldOblique.ttf', '/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSansMono.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSans-BoldOblique.ttf', '/usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoBd.ttf', '/usr/share/fonts/truetype/msttcorefonts/couri.ttf', '/usr/share/fonts/truetype/lyx/cmsy10.ttf', '/usr/share/fonts/truetype/msttcorefonts/arialbd.ttf', '/usr/share/fonts/truetype/msttcorefonts/timesbd.ttf', '/usr/share/fonts/truetype/lyx/msbm10.ttf', '/usr/share/fonts/truetype/msttcorefonts/Comic_Sans_MS.ttf', '/usr/share/fonts/truetype/msttcorefonts/Arial.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSans-ExtraLight.ttf', '/usr/share/fonts/truetype/lyx/esint10.ttf', '/usr/share/fonts/truetype/msttcorefonts/Courier_New.ttf', '/usr/share/fonts/truetype/msttcorefonts/Georgia_Bold_Italic.ttf', '/usr/share/fonts/truetype/msttcorefonts/verdana.ttf', '/usr/share/fonts/truetype/unfonts-core/UnDinaruLight.ttf', '/usr/share/fonts/truetype/unfonts-core/UnDotum.ttf', '/usr/share/fonts/truetype/lyx/cmmi10.ttf', '/usr/share/fonts/truetype/unfonts-core/UnPilgiBold.ttf', '/usr/share/fonts/truetype/msttcorefonts/impact.ttf', '/usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoIt.ttf', '/usr/share/fonts/truetype/msttcorefonts/Verdana_Italic.ttf', '/usr/share/fonts/truetype/msttcorefonts/Comic_Sans_MS_Bold.ttf', '/usr/share/fonts/truetype/msttcorefonts/verdanab.ttf', '/usr/share/fonts/truetype/unfonts-core/UnBatang.ttf', '/usr/share/fonts/truetype/msttcorefonts/georgia.ttf', '/usr/share/fonts/truetype/unfonts-core/UnDinaru.ttf', '/usr/share/fonts/truetype/unfonts-core/UnDinaruBold.ttf', '/usr/share/fonts/truetype/ttf-bitstream-vera/Vera.ttf', '/usr/share/fonts/truetype/msttcorefonts/courbi.ttf', '/usr/share/fonts/truetype/ttf-bitstream-vera/VeraMoBI.ttf', '/usr/share/fonts/truetype/lyx/cmex10.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSansMono-Bold.ttf', '/usr/share/fonts/truetype/msttcorefonts/cour.ttf', '/usr/share/fonts/truetype/msttcorefonts/Impact.ttf', '/usr/share/fonts/truetype/unfonts-core/UnGraphic.ttf', '/usr/share/fonts/truetype/dejavu/DejaVuSansCondensed-Bold.ttf', '/usr/share/fonts/truetype/lyx/rsfs10.ttf', '/usr/share/fonts/truetype/unfonts-core/UnDotumBold.ttf', '/usr/share/fonts/truetype/unfonts-core/UnBatangBold.ttf', '/usr/share/fonts/truetype/lyx/wasy10.ttf', '/usr/share/fonts/truetype/msttcorefonts/verdanai.ttf', '/usr/share/fonts/truetype/unfonts-core/UnGraphicBold.ttf', '/usr ...

# %%
#폰트 적용 방법 2 - FontProperties 사용

font_path = '/usr/share/fonts/truetype/unfonts-core/UnDotum.ttf'
fontProp = fm.FontProperties(fname = font_path, size=15)

data = np.random.randint(-100, 100, 50).cumsum()
plt.plot(range(50), data, 'r')
plt.title('가갸거겨', fontproperties = fontProp)
plt.ylabel('아메리카노', fontproperties = fontProp)
plt.xlabel('조아조아조아', fontproperties = fontProp)
# Out:
# Text(0.5, 0, '조아조아조아')

# %%
#폰트 적용 방법 3 - matplotlib.rcParams[]을 사용한 전역 폰트 설정

#'Un'으로 시작하는 폰트
f = [(f.name, f.fname) for f in fm.fontManager.ttflist if f.name[:2] == 'Un']
print(len(font_list))

f[:10]

print("default 폰트 사이즈 : ", plt.rcParams['font.size'])
print("default 폰트 : ", plt.rcParams['font.family'])

plt.rcParams['font.family'] = 'UnDotum'
print("default 폰트 : ", plt.rcParams['font.family'])

plt.plot(range(50), data, 'r')
plt.title('음메음메음메')
plt.ylabel('아메리카노')
plt.xlabel('시러시러시러')
# Out:
# 134
# default 폰트 사이즈 :  10.0
# default 폰트 :  ['Gmarket Sans TTF']
# default 폰트 :  ['UnDotum']
# Text(0.5, 0, '시러시러시러')
